# %%
import random

# %%
abc = ['e', 'd', 'a', 'c', 'b']
print(abc)

# 리스트에서 랜덤으로 원소 가져오기
random.choice(abc)
# Out:
# ['e', 'd', 'a', 'c', 'b']
# 'a'

# %%
# 1부터 9 사이의 랜덤 정수 가져오기
random.randint(1,9)
# Out:
# 2

# %%
random.randrange(2, 5, 2)
# Out:
# 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
