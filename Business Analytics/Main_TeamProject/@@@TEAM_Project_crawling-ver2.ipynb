# %%
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup as bs
import pandas as pd
import matplotlib.pyplot as plt
import time
from datetime import datetime, timedelta
from selenium.common.exceptions import NoSuchElementException

# %%
from selenium import webdriver

driver = webdriver.Chrome()

driver.implicitly_wait(3)

# %%
#최신순
#https://search.naver.com/search.naver?where=view&query=%22%EA%B5%AD%EB%A3%B0%22&sm=tab_opt&nso=so%3Add%2Cp%3Afrom20211201to20211215%2Ca%3Aall
#관련도순
#https://search.naver.com/search.naver?where=view&query=%22%EA%B5%AD%EB%A3%B0%22&sm=tab_opt&nso=so%3Ar%2Cp%3Afrom20211201to20211215

# %% [markdown]
# ---

# %%
hey = {}
for i in range(50):
    a = input("단어명: ")
    hey[f'{a}'] = pd.read_csv(f'빈도수 결과_{a}.csv')
# Out:
# 단어명: 2번남
# 단어명: G.O.A.T
# 단어명: h워얼v
# 단어명: 가심비
# 단어명: 갸루피스
# 단어명: 관짝밈
# 단어명: 국룰
# 단어명: 국힙원탑
# 단어명: 귀요미
# 단어명: 기모띠
# 단어명: 꿀잼
# 단어명: 나비보벳따우
# 단어명: 나심비
# 단어명: 낮져밤이
# 단어명: 너또다
# 단어명: 당모치
# 단어명: 대환장파티
# 단어명: 덕밍아웃
# 단어명: 등골 브레이커
# 단어명: 떼껄룩
# 단어명: 똥꼬충
# 단어명: 라떼는 말이야
# 단어명: 레알
# 단어명: 맘충
# 단어명: 머선129
# 단어명: 명존쎄
# 단어명: 모히또에서 몰디브
# 단어명: 몰-루
# 단어명: 무야호
# 단어명: 박박나나짜짜
# 단어명: 복세편살
# 단어명: 설참
# 단어명: 쉽살재빙
# 단어명: 실화냐
# 단어명: 씹선비
# 단어명: 오저치고
# 단어명: 오팬무
# 단어명: 제당슈만
# 단어명: 존버
# 단어명: 취존
# 단어명: 킹받
# 단어명: 탈룰라
# 단어명: 투머치토커
# 단어명: 티엠아이
# 단어명: 하입보이요
# 단어명: 합격목걸이
# 단어명: 햄최몇
# 단어명: 행복회로
# 단어명: 행쇼
# 단어명: 헬창

# %%
hey_2 = pd.concat(hey, axis=1)
hey_2.to_csv("dataset_777.csv", index=False, encoding='utf-8-sig')
print(f"csv파일 저장완료.")
# Out:
# csv파일 저장완료.

# %%
i
# Out:
#         "국룰"    "국룰".1
# 0        연/월  "국룰"_빈도수
# 1    2012/01         0
# 2    2012/02         9
# 3    2012/03        28
# 4    2012/04         5
# ..       ...       ...
# 139  2023/07       150
# 140  2023/08       150
# 141  2023/09       150
# 142  2023/10       150
# 143  2023/11       150
#
# [144 rows x 2 columns]

# %%
data_2 = pd.read_csv('data_2')


result_df = pd.concat([data_2,
                       ], axis=1)

# 결과를 새로운 CSV 파일로 저장
result_csv_path = '/path/to/result/file.csv'
result_df.to_csv(result_csv_path, index=False)

# %% [markdown]
# ---
# # 0.연도별 탐색
# ---

# %%
ww = input("탐색할 단어 : ")
word = ('"' + ww + '"')

print("2023년부터 연도별 빈도 탐색을 시작합니다.")
print("-----------------------------------------")

start = 20230101
end = 20231231

while True:
    start_date = str(start)
    end_date = str(end)

    period = "from" + start_date + "to" + end_date

    URL = "https://search.naver.com/search.naver?where=view&query=" + word + "&sm=tab_opt&nso=so%3Add%2Cp%3A" + period + "%2Ca%3Aall"
    driver.get(URL)

    # 끝까지 스크롤 내리기
    while True:
        last_height = driver.execute_script("return document.body.scrollHeight")
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(1)
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break

    list_1 = driver.find_elements("css selector", "#main_pack > section > more-contents > div > ul > li > div > div.detail_box > div.title_area > a")
    length = len(list_1)
    
    
    when = str(start)[:4]
    if length >= 150 :
        print(f"- {when}년 : {length}회 이상")
    else :
        print(f"- {when}년 : {length}회")

    # 조건 확인 및 종료
    if length < 100:
        break

    # start와 end 10000씩 줄이기
    start -= 10000
    end -= 10000

print("-----------------------------------------")
print("Searching finished.")
print("처음으로 150회 이하로 나오는 연도 포함한")
print("연도부터 월별 크롤링 시작하기")
# Out:
# 탐색할 단어 : 별다줄
# 2023년부터 연도별 빈도 탐색을 시작합니다.
# -----------------------------------------
# - 2023년 : 150회 이상
# - 2022년 : 150회 이상
# - 2021년 : 150회 이상
# - 2020년 : 150회 이상
# - 2019년 : 150회 이상
# - 2018년 : 150회 이상
# - 2017년 : 132회
# - 2016년 : 137회
# - 2015년 : 104회
# - 2014년 : 3회
# -----------------------------------------
# Searching finished.
# 처음으로 150회 이하로 나오는 연도 포함한
# 연도부터 월별 크롤링 시작하기

# %% [markdown]
# ___
# # 1. 월별 빈도수 리스트화
# ---
# ##### - 단어별 빈도수 리스트를 dataframes에 추가 후 csv저장

# %%
words = ['"개같이"', '"갬성"', '"현타"', '"슬세권"']

# %%
dataframes = {}

for w in words :
    print("★-★-★-★-★-★-★-★-★-★-★-★-★-★-★-★")
    print(f"탐색 중인 단어 : {w}")
    
    end = datetime(2023, 10, 31)
    start = end.replace(day=1) - timedelta(days=1)
    if end.day < start.day:
        start_ago = start.replace(day=end.day)

    print("------------------------------")

    period_list = []
    frequency_list = []

    while True:
        start_date = str(start.strftime('%Y%m%d'))
        end_date = str(end.strftime('%Y%m%d'))
        year = str(start_date)[:4]
        month = str(start_date)[4:6]

        period = "from" + start_date + "to" + end_date

        URL = "https://search.naver.com/search.naver?where=view&query=" + w + "&sm=tab_opt&nso=so%3Add%2Cp%3A" + period + "%2Ca%3Aall"
        driver.get(URL)

        # 끝까지 스크롤 내리기
        while True:
            last_height = driver.execute_script("return document.body.scrollHeight")
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(0.8)
            new_height = driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height:
                break
        
        # 결과 수집
        list_1 = driver.find_elements("css selector", "#main_pack > section > more-contents > div > ul > li > div > div.detail_box > div.title_area > a")
        length = len(list_1)
        if length <= 10 :
            time.sleep(3.5)

        # 프린트용 날짜 계산
        year_print = str(end_date)[:4]
        month_print = str(end_date)[4:6]    

        # 경과 출력
        print(f"{year_print}년 {month_print}월 : {length}회")

        # 월별 빈도수 리스트 저장
        period_list.append(f"{year_print}/{month_print}")
        frequency_list.append(length)

        # 조건 확인 및 break
        if length < 1 :
            break

        # 한달씩 줄이기
        end = end.replace(day=1) - timedelta(days=1)
        if end.day < end.day:
            end_ago = end.replace(day=end.day)
        start = end.replace(day=1) - timedelta(days=1)
        if end.day < start.day:
            start_ago = start.replace(day=end.day)

    print("Searching finished.")
    print("- - -")
    print("매크로 감지를 피하기 위해 5초간 대기")
    print("5", end=" ")
    time.sleep(0.95)
    print("4", end=" ")
    time.sleep(0.95)
    print("3", end=" ")
    time.sleep(0.95)
    print("2", end=" ")
    time.sleep(0.95)
    print("1", end=" ")
    time.sleep(0.95)
    print("0")
    print(" ")


    df = pd.DataFrame({'연/월' : period_list, 
                       f'{w}_빈도수': frequency_list
                      })
    df = df.sort_values(by = ['연/월'], ascending = True)

    dataframes[f"{w}"] = df


    start_ago = start.replace(day=end.day)

print("------------------------")

#period_list = []
#frequency_list = []

title_list = []
content_list = []
writer_list = []
date_list = []
null_element = 0

while True:
    start_date = str(start.strftime('%Y%m%d'))
    end_date = str(end.strftime('%Y%m%d'))
    year = str(start_date)[:4]
    month = str(start_date)[4:6]
    
    period = "from" + start_date + "to" + end_date

    URL = "https://search.naver.com/search.naver?where=view&query=" + word + "&sm=tab_opt&nso=so%3Add%2Cp%3A" + period + "%2Ca%3Aall"
    driver.get(URL)

    # 끝까지 스크롤 내리기
    while True:
        last_height = driver.execute_script("return document.body.scrollHeight")
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(0.8)
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break


    list_1 = driver.find_elements("css selector", "#main_pack > section > more-contents > div > ul > li > div > div.detail_box > div.title_area > a")
    length = len(list_1)

    # 프린트용 날짜 계산
    year_print = str(end_date)[:4]
    month_print = str(end_date)[4:6]    
    
    # 경과 출력
    print(f"- {year_print}년 {month_print}월 : {length}개")
    
    # 월별 빈도수 리스트 저장
    #period_list.append(f"{year_print}/{month_print}")
    #frequency_list.append(length)
    

    # 제목, 내용, 저자, 날짜 리스트에 담기
    elements = driver.find_elements("css selector", '#main_pack > section > more-contents > div > ul > li > div')

    for i, element in enumerate(elements, start=1):
        try:
            title = element.find_element("css selector", 'div.detail_box > div.title_area > a').text
            content = element.find_element("css selector", 'div > div.detail_box > div.dsc_area > a').text
            writer = element.find_element("css selector", 'div > div.user_box > div.user_box_inner > div > a').text
            date = element.find_element("css selector", 'div > div.user_box > div.user_box_inner > div > span').text

            #print("")
            #print(title)
            #print(content)
            #print(writer)
            #print(date)
            #print("----")

            title_list.append(title)
            content_list.append(content)
            writer_list.append(writer)
            date_list.append(date)

        except NoSuchElementException:
            #print("")
            #print(f"Null({i})")
            null_element += 1


    # 조건 확인 및 break
    if length < 1 :
        break

    # 한달씩 줄이기
    end = end.replace(day=1) - timedelta(days=1)
    if end.day < end.day:
        end_ago = end.replace(day=end.day)
    start = end.replace(day=1) - timedelta(days=1)
    if end.day < start.day:
        start_ago = start.replace(day=end.day)

print("------------------------")
print(f"({null_element} null_element counted)")
print("Searching finished.")


#df = pd.DataFrame({'연/월' : period_list, 
#                   '빈도 수': frequency_list
#                  })
#df = df.sort_values(by = ['연/월'], ascending = True)
#dataframes_test[f'{w}'] = df

df_contents = pd.DataFrame({'제목': title_list, 
                    '내용': content_list, 
                    '게시자': writer_list, 
                    '게시날짜': date_list
                    })
dataframes_contents_test[f'{w}'] = df_contents

#----------------------------------------------------

# 빈도수 리스트 저장
#dataframes_test[f'{w}'].to_csv(f'{w}_Frequency_per_Month.csv', index=False, encoding='utf-8-sig')
# 제목/내용/게시자/날짜 저장
dataframes_contents_test[f'{w}'].to_csv(f'{w}_제목_관련내용_게시자_게시날짜_{y}{m}{d}까지.csv', index=False, encoding='utf-8-sig')

print("- - -")
print("csv file Saved.")
# Out:
# 탐색할 단어 : 오운완
# 탐색시작 연 입력 (yyyy) : 2021
# 탐색시작 월 입력 (m) : 11
# 탐색시작 일 입력 (d) : 30
# ------------------------
# - 2021년 11월 : 150개
# - 2021년 10월 : 98개
# - 2021년 09월 : 33개
# - 2021년 08월 : 30개
# - 2021년 07월 : 27개
# - 2021년 06월 : 21개
# - 2021년 05월 : 21개
# - 2021년 04월 : 10개
# - 2021년 03월 : 5개
# - 2021년 02월 : 6개
# - 2021년 01월 : 7개
# - 2020년 12월 : 12개
# - 2020년 11월 : 15개
# - 2020년 10월 : 6개
# - 2020년 09월 : 10개
# - 2020년 08월 : 5개
# - 2020년 07월 : 4개
# - 2020년 06월 : 1개
# - 2020년 05월 : 2개
# - 2020년 04월 : 2개
# - 2020년 03월 : 10개
# - 2020년 02월 : 13개
# - 2020년 01월 : 3개
# - 2019년 12월 : 6개
# - 2019년 11월 : 3개
# - 2019년 10월 : 2개
# - 2019년 09월 : 0개
# ------------------------
# (99 null_element counted)
# Searching finished.
# - - -
# csv file Saved.

# %% [markdown]
# ### 3개월 이내 내용 크롤링

# %%
words2 = ['"어쩔티비"', '"점메추"', '"스불재"', '"이왜진"', '"맑눈광"', '"폭룡적"', '"많관부"', '"갑분싸"']

# %%
w2 = '어쩔티비'
word2 = '"' + w2 + '"'
print(f'탐색할 단어 : {w2}')

#dataframes_test = {}
dataframes_contents_test = {}

y = 2023
m = 11
d = 25

end = datetime(y, m, d)
start = end.replace(day=1) - timedelta(days=1)
if end.day < start.day:
    start_ago = start.replace(day=end.day)

print("------------------------")

#period_list = []
#frequency_list = []

title_list = []
content_list = []
writer_list = []
date_list = []
null_element = 0

repeat_count = 0

while True:
    start_date = str(start.strftime('%Y%m%d'))
    end_date = str(end.strftime('%Y%m%d'))
    year = str(start_date)[:4]
    month = str(start_date)[4:6]

    period = "from" + start_date + "to" + end_date

    URL = "https://search.naver.com/search.naver?where=view&query=" + word2+ "&sm=tab_opt&nso=so%3Add%2Cp%3A" + period + "%2Ca%3Aall"
    driver.get(URL)

    # 끝까지 스크롤 내리기
    while True:
        last_height = driver.execute_script("return document.body.scrollHeight")
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(0.8)
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break


    list_1 = driver.find_elements("css selector", "#main_pack > section > more-contents > div > ul > li > div > div.detail_box > div.title_area > a")
    length = len(list_1)

    # 프린트용 날짜 계산
    year_print = str(end_date)[:4]
    month_print = str(end_date)[4:6]    

    # 경과 출력
    print(f"- {year_print}년 {month_print}월 : {length}개")

    # 월별 빈도수 리스트 저장
    #period_list.append(f"{year_print}/{month_print}")
    #frequency_list.append(length)


    # 제목, 내용, 저자, 날짜 리스트에 담기
    elements = driver.find_elements("css selector", '#main_pack > section > more-contents > div > ul > li > div')

    for i, element in enumerate(elements, start=1):
        try:
            title = element.find_element("css selector", 'div.detail_box > div.title_area > a').text
            content = element.find_element("css selector", 'div > div.detail_box > div.dsc_area > a').text
            writer = element.find_element("css selector", 'div > div.user_box > div.user_box_inner > div > a').text
            date = element.find_element("css selector", 'div > div.user_box > div.user_box_inner > div > span').text

            #print("")
            #print(title)
            #print(content)
            #print(writer)
            #print(date)
            #print("----")

            title_list.append(title)
            content_list.append(content)
            writer_list.append(writer)
            date_list.append(date)

        except NoSuchElementException:
            #print("")
            #print(f"Null({i})")
            null_element += 1


    # 조건 확인 및 break
    if repeat_count == 2 :
        break

    # 한달씩 줄이기
    end = end.replace(day=1) - timedelta(days=1)
    if end.day < end.day:
        end_ago = end.replace(day=end.day)
    start = end.replace(day=1) - timedelta(days=1)
    if end.day < start.day:
        start_ago = start.replace(day=end.day)

    repeat_count += 1

print("------------------------")
print(f"({null_element} null_element counted)")
print("Searching finished.")


#df = pd.DataFrame({'연/월' : period_list, 
#                   '빈도 수': frequency_list
#                  })
#df = df.sort_values(by = ['연/월'], ascending = True)
#dataframes_test[f'{w}'] = df

df_contents = pd.DataFrame({'제목': title_list, 
                    '내용': content_list, 
                    '게시자': writer_list, 
                    '게시날짜': date_list
                    })
dataframes_contents_test[f'{w2}'] = df_contents

#----------------------------------------------------

# 빈도수 리스트 저장
#dataframes_test[f'{w}'].to_csv(f'{w}_Frequency_per_Month.csv', index=False, encoding='utf-8-sig')
# 제목/내용/게시자/날짜 저장
dataframes_contents_test[f'{w2}'].to_csv(f'{w2}_제목_관련내용_게시자_게시날짜_{y}{m}{d}까지.csv', index=False, encoding='utf-8-sig')

print("- - -")
print("csv file Saved.")
# Out:
# 탐색할 단어 : 어쩔티비
# ------------------------
# - 2023년 11월 : 150개
# - 2023년 10월 : 150개
# - 2023년 09월 : 150개
# ------------------------
# (61 null_element counted)
# Searching finished.
# - - -
# csv file Saved.

# %%
w2 = '점메추'
word2 = '"' + w2 + '"'
print(f'탐색할 단어 : {w2}')

#dataframes_test = {}
dataframes_contents_test = {}

y = 2023
m = 11
d = 25

end = datetime(y, m, d)
start = end.replace(day=1) - timedelta(days=1)
if end.day < start.day:
    start_ago = start.replace(day=end.day)

print("------------------------")

#period_list = []
#frequency_list = []

title_list = []
content_list = []
writer_list = []
date_list = []
null_element = 0

repeat_count = 0

while True:
    start_date = str(start.strftime('%Y%m%d'))
    end_date = str(end.strftime('%Y%m%d'))
    year = str(start_date)[:4]
    month = str(start_date)[4:6]

    period = "from" + start_date + "to" + end_date

    URL = "https://search.naver.com/search.naver?where=view&query=" + word2+ "&sm=tab_opt&nso=so%3Add%2Cp%3A" + period + "%2Ca%3Aall"
    driver.get(URL)

    # 끝까지 스크롤 내리기
    while True:
        last_height = driver.execute_script("return document.body.scrollHeight")
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(0.8)
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break


    list_1 = driver.find_elements("css selector", "#main_pack > section > more-contents > div > ul > li > div > div.detail_box > div.title_area > a")
    length = len(list_1)

    # 프린트용 날짜 계산
    year_print = str(end_date)[:4]
    month_print = str(end_date)[4:6]    

    # 경과 출력
    print(f"- {year_print}년 {month_print}월 : {length}개")

    # 월별 빈도수 리스트 저장
    #period_list.append(f"{year_print}/{month_print}")
    #frequency_list.append(length)


    # 제목, 내용, 저자, 날짜 리스트에 담기
    elements = driver.find_elements("css selector", '#main_pack > section > more-contents > div > ul > li > div')

    for i, element in enumerate(elements, start=1):
        try:
            title = element.find_element("css selector", 'div.detail_box > div.title_area > a').text
            content = element.find_element("css selector", 'div > div.detail_box > div.dsc_area > a').text
            writer = element.find_element("css selector", 'div > div.user_box > div.user_box_inner > div > a').text
            date = element.find_element("css selector", 'div > div.user_box > div.user_box_inner > div > span').text

            #print("")
            #print(title)
            #print(content)
            #print(writer)
            #print(date)
            #print("----")

            title_list.append(title)
            content_list.append(content)
            writer_list.append(writer)
            date_list.append(date)

        except NoSuchElementException:
            #print("")
            #print(f"Null({i})")
            null_element += 1


    # 조건 확인 및 break
    if repeat_count == 2 :
        break

    # 한달씩 줄이기
    end = end.replace(day=1) - timedelta(days=1)
    if end.day < end.day:
        end_ago = end.replace(day=end.day)
    start = end.replace(day=1) - timedelta(days=1)
    if end.day < start.day:
        start_ago = start.replace(day=end.day)

    repeat_count += 1

print("------------------------")
print(f"({null_element} null_element counted)")
print("Searching finished.")


#df = pd.DataFrame({'연/월' : period_list, 
#                   '빈도 수': frequency_list
#                  })
#df = df.sort_values(by = ['연/월'], ascending = True)
#dataframes_test[f'{w}'] = df

df_contents = pd.DataFrame({'제목': title_list, 
                    '내용': content_list, 
                    '게시자': writer_list, 
                    '게시날짜': date_list
                    })
dataframes_contents_test[f'{w2}'] = df_contents

#----------------------------------------------------

# 빈도수 리스트 저장
#dataframes_test[f'{w}'].to_csv(f'{w}_Frequency_per_Month.csv', index=False, encoding='utf-8-sig')
# 제목/내용/게시자/날짜 저장
dataframes_contents_test[f'{w2}'].to_csv(f'{w2}_제목_관련내용_게시자_게시날짜_{y}{m}{d}까지.csv', index=False, encoding='utf-8-sig')

print("- - -")
print("csv file Saved.")
# Out:
# 탐색할 단어 : 점메추
# ------------------------
# - 2023년 11월 : 150개
# - 2023년 10월 : 150개
# - 2023년 09월 : 150개
# ------------------------
# (216 null_element counted)
# Searching finished.
# - - -
# csv file Saved.

# %%
w2 = '스불재'
word2 = '"' + w2 + '"'
print(f'탐색할 단어 : {w2}')

#dataframes_test = {}
dataframes_contents_test = {}

y = 2023
m = 11
d = 25

end = datetime(y, m, d)
start = end.replace(day=1) - timedelta(days=1)
if end.day < start.day:
    start_ago = start.replace(day=end.day)

print("------------------------")

#period_list = []
#frequency_list = []

title_list = []
content_list = []
writer_list = []
date_list = []
null_element = 0

repeat_count = 0

while True:
    start_date = str(start.strftime('%Y%m%d'))
    end_date = str(end.strftime('%Y%m%d'))
    year = str(start_date)[:4]
    month = str(start_date)[4:6]

    period = "from" + start_date + "to" + end_date

    URL = "https://search.naver.com/search.naver?where=view&query=" + word2+ "&sm=tab_opt&nso=so%3Add%2Cp%3A" + period + "%2Ca%3Aall"
    driver.get(URL)

    # 끝까지 스크롤 내리기
    while True:
        last_height = driver.execute_script("return document.body.scrollHeight")
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(0.8)
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break


    list_1 = driver.find_elements("css selector", "#main_pack > section > more-contents > div > ul > li > div > div.detail_box > div.title_area > a")
    length = len(list_1)

    # 프린트용 날짜 계산
    year_print = str(end_date)[:4]
    month_print = str(end_date)[4:6]    

    # 경과 출력
    print(f"- {year_print}년 {month_print}월 : {length}개")

    # 월별 빈도수 리스트 저장
    #period_list.append(f"{year_print}/{month_print}")
    #frequency_list.append(length)


    # 제목, 내용, 저자, 날짜 리스트에 담기
    elements = driver.find_elements("css selector", '#main_pack > section > more-contents > div > ul > li > div')

    for i, element in enumerate(elements, start=1):
        try:
            title = element.find_element("css selector", 'div.detail_box > div.title_area > a').text
            content = element.find_element("css selector", 'div > div.detail_box > div.dsc_area > a').text
            writer = element.find_element("css selector", 'div > div.user_box > div.user_box_inner > div > a').text
            date = element.find_element("css selector", 'div > div.user_box > div.user_box_inner > div > span').text

            #print("")
            #print(title)
            #print(content)
            #print(writer)
            #print(date)
            #print("----")

            title_list.append(title)
            content_list.append(content)
            writer_list.append(writer)
            date_list.append(date)

        except NoSuchElementException:
            #print("")
            #print(f"Null({i})")
            null_element += 1


    # 조건 확인 및 break
    if repeat_count == 2 :
        break

    # 한달씩 줄이기
    end = end.replace(day=1) - timedelta(days=1)
    if end.day < end.day:
        end_ago = end.replace(day=end.day)
    start = end.replace(day=1) - timedelta(days=1)
    if end.day < start.day:
        start_ago = start.replace(day=end.day)

    repeat_count += 1

print("------------------------")
print(f"({null_element} null_element counted)")
print("Searching finished.")


#df = pd.DataFrame({'연/월' : period_list, 
#                   '빈도 수': frequency_list
#                  })
#df = df.sort_values(by = ['연/월'], ascending = True)
#dataframes_test[f'{w}'] = df

df_contents = pd.DataFrame({'제목': title_list, 
                    '내용': content_list, 
                    '게시자': writer_list, 
                    '게시날짜': date_list
                    })
dataframes_contents_test[f'{w2}'] = df_contents

#----------------------------------------------------

# 빈도수 리스트 저장
#dataframes_test[f'{w}'].to_csv(f'{w}_Frequency_per_Month.csv', index=False, encoding='utf-8-sig')
# 제목/내용/게시자/날짜 저장
dataframes_contents_test[f'{w2}'].to_csv(f'{w2}_제목_관련내용_게시자_게시날짜_{y}{m}{d}까지.csv', index=False, encoding='utf-8-sig')

print("- - -")
print("csv file Saved.")
# Out:
# 탐색할 단어 : 스불재
# ------------------------
# - 2023년 11월 : 150개
# - 2023년 10월 : 150개
# - 2023년 09월 : 150개
# ------------------------
# (40 null_element counted)
# Searching finished.
# - - -
# csv file Saved.

# %%
w2 = '이왜진'
word2 = '"' + w2 + '"'
print(f'탐색할 단어 : {w2}')

#dataframes_test = {}
dataframes_contents_test = {}

y = 2023
m = 11
d = 25

end = datetime(y, m, d)
start = end.replace(day=1) - timedelta(days=1)
if end.day < start.day:
    start_ago = start.replace(day=end.day)

print("------------------------")

#period_list = []
#frequency_list = []

title_list = []
content_list = []
writer_list = []
date_list = []
null_element = 0

repeat_count = 0

while True:
    start_date = str(start.strftime('%Y%m%d'))
    end_date = str(end.strftime('%Y%m%d'))
    year = str(start_date)[:4]
    month = str(start_date)[4:6]

    period = "from" + start_date + "to" + end_date

    URL = "https://search.naver.com/search.naver?where=view&query=" + word2+ "&sm=tab_opt&nso=so%3Add%2Cp%3A" + period + "%2Ca%3Aall"
    driver.get(URL)

    # 끝까지 스크롤 내리기
    while True:
        last_height = driver.execute_script("return document.body.scrollHeight")
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(0.8)
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break


    list_1 = driver.find_elements("css selector", "#main_pack > section > more-contents > div > ul > li > div > div.detail_box > div.title_area > a")
    length = len(list_1)

    # 프린트용 날짜 계산
    year_print = str(end_date)[:4]
    month_print = str(end_date)[4:6]    

    # 경과 출력
    print(f"- {year_print}년 {month_print}월 : {length}개")

    # 월별 빈도수 리스트 저장
    #period_list.append(f"{year_print}/{month_print}")
    #frequency_list.append(length)


    # 제목, 내용, 저자, 날짜 리스트에 담기
    elements = driver.find_elements("css selector", '#main_pack > section > more-contents > div > ul > li > div')

    for i, element in enumerate(elements, start=1):
        try:
            title = element.find_element("css selector", 'div.detail_box > div.title_area > a').text
            content = element.find_element("css selector", 'div > div.detail_box > div.dsc_area > a').text
            writer = element.find_element("css selector", 'div > div.user_box > div.user_box_inner > div > a').text
            date = element.find_element("css selector", 'div > div.user_box > div.user_box_inner > div > span').text

            #print("")
            #print(title)
            #print(content)
            #print(writer)
            #print(date)
            #print("----")

            title_list.append(title)
            content_list.append(content)
            writer_list.append(writer)
            date_list.append(date)

        except NoSuchElementException:
            #print("")
            #print(f"Null({i})")
            null_element += 1


    # 조건 확인 및 break
    if repeat_count == 2 :
        break

    # 한달씩 줄이기
    end = end.replace(day=1) - timedelta(days=1)
    if end.day < end.day:
        end_ago = end.replace(day=end.day)
    start = end.replace(day=1) - timedelta(days=1)
    if end.day < start.day:
        start_ago = start.replace(day=end.day)

    repeat_count += 1

print("------------------------")
print(f"({null_element} null_element counted)")
print("Searching finished.")


#df = pd.DataFrame({'연/월' : period_list, 
#                   '빈도 수': frequency_list
#                  })
#df = df.sort_values(by = ['연/월'], ascending = True)
#dataframes_test[f'{w}'] = df

df_contents = pd.DataFrame({'제목': title_list, 
                    '내용': content_list, 
                    '게시자': writer_list, 
                    '게시날짜': date_list
                    })
dataframes_contents_test[f'{w2}'] = df_contents

#----------------------------------------------------

# 빈도수 리스트 저장
#dataframes_test[f'{w}'].to_csv(f'{w}_Frequency_per_Month.csv', index=False, encoding='utf-8-sig')
# 제목/내용/게시자/날짜 저장
dataframes_contents_test[f'{w2}'].to_csv(f'{w2}_제목_관련내용_게시자_게시날짜_{y}{m}{d}까지.csv', index=False, encoding='utf-8-sig')

print("- - -")
print("csv file Saved.")
# Out:
# 탐색할 단어 : 이왜진
# ------------------------
# - 2023년 11월 : 150개
# - 2023년 10월 : 150개
# - 2023년 09월 : 150개
# ------------------------
# (90 null_element counted)
# Searching finished.
# - - -
# csv file Saved.

# %%
w2 = '맑눈광'
word2 = '"' + w2 + '"'
print(f'탐색할 단어 : {w2}')

#dataframes_test = {}
dataframes_contents_test = {}

y = 2023
m = 11
d = 25

end = datetime(y, m, d)
start = end.replace(day=1) - timedelta(days=1)
if end.day < start.day:
    start_ago = start.replace(day=end.day)

print("------------------------")

#period_list = []
#frequency_list = []

title_list = []
content_list = []
writer_list = []
date_list = []
null_element = 0

repeat_count = 0

while True:
    start_date = str(start.strftime('%Y%m%d'))
    end_date = str(end.strftime('%Y%m%d'))
    year = str(start_date)[:4]
    month = str(start_date)[4:6]

    period = "from" + start_date + "to" + end_date

    URL = "https://search.naver.com/search.naver?where=view&query=" + word2+ "&sm=tab_opt&nso=so%3Add%2Cp%3A" + period + "%2Ca%3Aall"
    driver.get(URL)

    # 끝까지 스크롤 내리기
    while True:
        last_height = driver.execute_script("return document.body.scrollHeight")
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(0.8)
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break


    list_1 = driver.find_elements("css selector", "#main_pack > section > more-contents > div > ul > li > div > div.detail_box > div.title_area > a")
    length = len(list_1)

    # 프린트용 날짜 계산
    year_print = str(end_date)[:4]
    month_print = str(end_date)[4:6]    

    # 경과 출력
    print(f"- {year_print}년 {month_print}월 : {length}개")

    # 월별 빈도수 리스트 저장
    #period_list.append(f"{year_print}/{month_print}")
    #frequency_list.append(length)


    # 제목, 내용, 저자, 날짜 리스트에 담기
    elements = driver.find_elements("css selector", '#main_pack > section > more-contents > div > ul > li > div')

    for i, element in enumerate(elements, start=1):
        try:
            title = element.find_element("css selector", 'div.detail_box > div.title_area > a').text
            content = element.find_element("css selector", 'div > div.detail_box > div.dsc_area > a').text
            writer = element.find_element("css selector", 'div > div.user_box > div.user_box_inner > div > a').text
            date = element.find_element("css selector", 'div > div.user_box > div.user_box_inner > div > span').text

            #print("")
            #print(title)
            #print(content)
            #print(writer)
            #print(date)
            #print("----")

            title_list.append(title)
            content_list.append(content)
            writer_list.append(writer)
            date_list.append(date)

        except NoSuchElementException:
            #print("")
            #print(f"Null({i})")
            null_element += 1


    # 조건 확인 및 break
    if repeat_count == 2 :
        break

    # 한달씩 줄이기
    end = end.replace(day=1) - timedelta(days=1)
    if end.day < end.day:
        end_ago = end.replace(day=end.day)
    start = end.replace(day=1) - timedelta(days=1)
    if end.day < start.day:
        start_ago = start.replace(day=end.day)

    repeat_count += 1

print("------------------------")
print(f"({null_element} null_element counted)")
print("Searching finished.")


#df = pd.DataFrame({'연/월' : period_list, 
#                   '빈도 수': frequency_list
#                  })
#df = df.sort_values(by = ['연/월'], ascending = True)
#dataframes_test[f'{w}'] = df

df_contents = pd.DataFrame({'제목': title_list, 
                    '내용': content_list, 
                    '게시자': writer_list, 
                    '게시날짜': date_list
                    })
dataframes_contents_test[f'{w2}'] = df_contents

#----------------------------------------------------

# 빈도수 리스트 저장
#dataframes_test[f'{w}'].to_csv(f'{w}_Frequency_per_Month.csv', index=False, encoding='utf-8-sig')
# 제목/내용/게시자/날짜 저장
dataframes_contents_test[f'{w2}'].to_csv(f'{w2}_제목_관련내용_게시자_게시날짜_{y}{m}{d}까지.csv', index=False, encoding='utf-8-sig')

print("- - -")
print("csv file Saved.")
# Out:
# 탐색할 단어 : 맑눈광
# ------------------------
# - 2023년 11월 : 150개
# - 2023년 10월 : 150개
# - 2023년 09월 : 150개
# ------------------------
# (101 null_element counted)
# Searching finished.
# - - -
# csv file Saved.

# %%
w2 = '폭룡적'
word2 = '"' + w2 + '"'
print(f'탐색할 단어 : {w2}')

#dataframes_test = {}
dataframes_contents_test = {}

y = 2023
m = 11
d = 25

end = datetime(y, m, d)
start = end.replace(day=1) - timedelta(days=1)
if end.day < start.day:
    start_ago = start.replace(day=end.day)

print("------------------------")

#period_list = []
#frequency_list = []

title_list = []
content_list = []
writer_list = []
date_list = []
null_element = 0

repeat_count = 0

while True:
    start_date = str(start.strftime('%Y%m%d'))
    end_date = str(end.strftime('%Y%m%d'))
    year = str(start_date)[:4]
    month = str(start_date)[4:6]

    period = "from" + start_date + "to" + end_date

    URL = "https://search.naver.com/search.naver?where=view&query=" + word2+ "&sm=tab_opt&nso=so%3Add%2Cp%3A" + period + "%2Ca%3Aall"
    driver.get(URL)

    # 끝까지 스크롤 내리기
    while True:
        last_height = driver.execute_script("return document.body.scrollHeight")
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(0.8)
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break


    list_1 = driver.find_elements("css selector", "#main_pack > section > more-contents > div > ul > li > div > div.detail_box > div.title_area > a")
    length = len(list_1)

    # 프린트용 날짜 계산
    year_print = str(end_date)[:4]
    month_print = str(end_date)[4:6]    

    # 경과 출력
    print(f"- {year_print}년 {month_print}월 : {length}개")

    # 월별 빈도수 리스트 저장
    #period_list.append(f"{year_print}/{month_print}")
    #frequency_list.append(length)


    # 제목, 내용, 저자, 날짜 리스트에 담기
    elements = driver.find_elements("css selector", '#main_pack > section > more-contents > div > ul > li > div')

    for i, element in enumerate(elements, start=1):
        try:
            title = element.find_element("css selector", 'div.detail_box > div.title_area > a').text
            content = element.find_element("css selector", 'div > div.detail_box > div.dsc_area > a').text
            writer = element.find_element("css selector", 'div > div.user_box > div.user_box_inner > div > a').text
            date = element.find_element("css selector", 'div > div.user_box > div.user_box_inner > div > span').text

            #print("")
            #print(title)
            #print(content)
            #print(writer)
            #print(date)
            #print("----")

            title_list.append(title)
            content_list.append(content)
            writer_list.append(writer)
            date_list.append(date)

        except NoSuchElementException:
            #print("")
            #print(f"Null({i})")
            null_element += 1


    # 조건 확인 및 break
    if repeat_count == 2 :
        break

    # 한달씩 줄이기
    end = end.replace(day=1) - timedelta(days=1)
    if end.day < end.day:
        end_ago = end.replace(day=end.day)
    start = end.replace(day=1) - timedelta(days=1)
    if end.day < start.day:
        start_ago = start.replace(day=end.day)

    repeat_count += 1

print("------------------------")
print(f"({null_element} null_element counted)")
print("Searching finished.")


#df = pd.DataFrame({'연/월' : period_list, 
#                   '빈도 수': frequency_list
#                  })
#df = df.sort_values(by = ['연/월'], ascending = True)
#dataframes_test[f'{w}'] = df

df_contents = pd.DataFrame({'제목': title_list, 
                    '내용': content_list, 
                    '게시자': writer_list, 
                    '게시날짜': date_list
                    })
dataframes_contents_test[f'{w2}'] = df_contents

#----------------------------------------------------

# 빈도수 리스트 저장
#dataframes_test[f'{w}'].to_csv(f'{w}_Frequency_per_Month.csv', index=False, encoding='utf-8-sig')
# 제목/내용/게시자/날짜 저장
dataframes_contents_test[f'{w2}'].to_csv(f'{w2}_제목_관련내용_게시자_게시날짜_{y}{m}{d}까지.csv', index=False, encoding='utf-8-sig')

print("- - -")
print("csv file Saved.")
# Out:
# 탐색할 단어 : 폭룡적
# ------------------------
# - 2023년 11월 : 150개
# - 2023년 10월 : 150개
# - 2023년 09월 : 141개
# ------------------------
# (58 null_element counted)
# Searching finished.
# - - -
# csv file Saved.

# %%
w2 = '많관부'
word2 = '"' + w2 + '"'
print(f'탐색할 단어 : {w2}')

#dataframes_test = {}
dataframes_contents_test = {}

y = 2023
m = 11
d = 25

end = datetime(y, m, d)
start = end.replace(day=1) - timedelta(days=1)
if end.day < start.day:
    start_ago = start.replace(day=end.day)

print("------------------------")

#period_list = []
#frequency_list = []

title_list = []
content_list = []
writer_list = []
date_list = []
null_element = 0

repeat_count = 0

while True:
    start_date = str(start.strftime('%Y%m%d'))
    end_date = str(end.strftime('%Y%m%d'))
    year = str(start_date)[:4]
    month = str(start_date)[4:6]

    period = "from" + start_date + "to" + end_date

    URL = "https://search.naver.com/search.naver?where=view&query=" + word2+ "&sm=tab_opt&nso=so%3Add%2Cp%3A" + period + "%2Ca%3Aall"
    driver.get(URL)

    # 끝까지 스크롤 내리기
    while True:
        last_height = driver.execute_script("return document.body.scrollHeight")
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(0.8)
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break


    list_1 = driver.find_elements("css selector", "#main_pack > section > more-contents > div > ul > li > div > div.detail_box > div.title_area > a")
    length = len(list_1)

    # 프린트용 날짜 계산
    year_print = str(end_date)[:4]
    month_print = str(end_date)[4:6]    

    # 경과 출력
    print(f"- {year_print}년 {month_print}월 : {length}개")

    # 월별 빈도수 리스트 저장
    #period_list.append(f"{year_print}/{month_print}")
    #frequency_list.append(length)


    # 제목, 내용, 저자, 날짜 리스트에 담기
    elements = driver.find_elements("css selector", '#main_pack > section > more-contents > div > ul > li > div')

    for i, element in enumerate(elements, start=1):
        try:
            title = element.find_element("css selector", 'div.detail_box > div.title_area > a').text
            content = element.find_element("css selector", 'div > div.detail_box > div.dsc_area > a').text
            writer = element.find_element("css selector", 'div > div.user_box > div.user_box_inner > div > a').text
            date = element.find_element("css selector", 'div > div.user_box > div.user_box_inner > div > span').text

            #print("")
            #print(title)
            #print(content)
            #print(writer)
            #print(date)
            #print("----")

            title_list.append(title)
            content_list.append(content)
            writer_list.append(writer)
            date_list.append(date)

        except NoSuchElementException:
            #print("")
            #print(f"Null({i})")
            null_element += 1


    # 조건 확인 및 break
    if repeat_count == 2 :
        break

    # 한달씩 줄이기
    end = end.replace(day=1) - timedelta(days=1)
    if end.day < end.day:
        end_ago = end.replace(day=end.day)
    start = end.replace(day=1) - timedelta(days=1)
    if end.day < start.day:
        start_ago = start.replace(day=end.day)

    repeat_count += 1

print("------------------------")
print(f"({null_element} null_element counted)")
print("Searching finished.")


#df = pd.DataFrame({'연/월' : period_list, 
#                   '빈도 수': frequency_list
#                  })
#df = df.sort_values(by = ['연/월'], ascending = True)
#dataframes_test[f'{w}'] = df

df_contents = pd.DataFrame({'제목': title_list, 
                    '내용': content_list, 
                    '게시자': writer_list, 
                    '게시날짜': date_list
                    })
dataframes_contents_test[f'{w2}'] = df_contents

#----------------------------------------------------

# 빈도수 리스트 저장
#dataframes_test[f'{w}'].to_csv(f'{w}_Frequency_per_Month.csv', index=False, encoding='utf-8-sig')
# 제목/내용/게시자/날짜 저장
dataframes_contents_test[f'{w2}'].to_csv(f'{w2}_제목_관련내용_게시자_게시날짜_{y}{m}{d}까지.csv', index=False, encoding='utf-8-sig')

print("- - -")
print("csv file Saved.")
# Out:
# 탐색할 단어 : 많관부
# ------------------------
# - 2023년 11월 : 150개
# - 2023년 10월 : 150개
# - 2023년 09월 : 150개
# ------------------------
# (80 null_element counted)
# Searching finished.
# - - -
# csv file Saved.

# %%
w2 = '갑분싸'
word2 = '"' + w2 + '"'
print(f'탐색할 단어 : {w2}')

#dataframes_test = {}
dataframes_contents_test = {}

y = 2023
m = 11
d = 25

end = datetime(y, m, d)
start = end.replace(day=1) - timedelta(days=1)
if end.day < start.day:
    start_ago = start.replace(day=end.day)

print("------------------------")

#period_list = []
#frequency_list = []

title_list = []
content_list = []
writer_list = []
date_list = []
null_element = 0

repeat_count = 0

while True:
    start_date = str(start.strftime('%Y%m%d'))
    end_date = str(end.strftime('%Y%m%d'))
    year = str(start_date)[:4]
    month = str(start_date)[4:6]

    period = "from" + start_date + "to" + end_date

    URL = "https://search.naver.com/search.naver?where=view&query=" + word2+ "&sm=tab_opt&nso=so%3Add%2Cp%3A" + period + "%2Ca%3Aall"
    driver.get(URL)

    # 끝까지 스크롤 내리기
    while True:
        last_height = driver.execute_script("return document.body.scrollHeight")
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(0.8)
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break


    list_1 = driver.find_elements("css selector", "#main_pack > section > more-contents > div > ul > li > div > div.detail_box > div.title_area > a")
    length = len(list_1)

    # 프린트용 날짜 계산
    year_print = str(end_date)[:4]
    month_print = str(end_date)[4:6]    

    # 경과 출력
    print(f"- {year_print}년 {month_print}월 : {length}개")

    # 월별 빈도수 리스트 저장
    #period_list.append(f"{year_print}/{month_print}")
    #frequency_list.append(length)


    # 제목, 내용, 저자, 날짜 리스트에 담기
    elements = driver.find_elements("css selector", '#main_pack > section > more-contents > div > ul > li > div')

    for i, element in enumerate(elements, start=1):
        try:
            title = element.find_element("css selector", 'div.detail_box > div.title_area > a').text
            content = element.find_element("css selector", 'div > div.detail_box > div.dsc_area > a').text
            writer = element.find_element("css selector", 'div > div.user_box > div.user_box_inner > div > a').text
            date = element.find_element("css selector", 'div > div.user_box > div.user_box_inner > div > span').text

            #print("")
            #print(title)
            #print(content)
            #print(writer)
            #print(date)
            #print("----")

            title_list.append(title)
            content_list.append(content)
            writer_list.append(writer)
            date_list.append(date)

        except NoSuchElementException:
            #print("")
            #print(f"Null({i})")
            null_element += 1


    # 조건 확인 및 break
    if repeat_count == 2 :
        break

    # 한달씩 줄이기
    end = end.replace(day=1) - timedelta(days=1)
    if end.day < end.day:
        end_ago = end.replace(day=end.day)
    start = end.replace(day=1) - timedelta(days=1)
    if end.day < start.day:
        start_ago = start.replace(day=end.day)

    repeat_count += 1

print("------------------------")
print(f"({null_element} null_element counted)")
print("Searching finished.")


#df = pd.DataFrame({'연/월' : period_list, 
#                   '빈도 수': frequency_list
#                  })
#df = df.sort_values(by = ['연/월'], ascending = True)
#dataframes_test[f'{w}'] = df

df_contents = pd.DataFrame({'제목': title_list, 
                    '내용': content_list, 
                    '게시자': writer_list, 
                    '게시날짜': date_list
                    })
dataframes_contents_test[f'{w2}'] = df_contents

#----------------------------------------------------

# 빈도수 리스트 저장
#dataframes_test[f'{w}'].to_csv(f'{w}_Frequency_per_Month.csv', index=False, encoding='utf-8-sig')
# 제목/내용/게시자/날짜 저장
dataframes_contents_test[f'{w2}'].to_csv(f'{w2}_제목_관련내용_게시자_게시날짜_{y}{m}{d}까지.csv', index=False, encoding='utf-8-sig')

print("- - -")
print("csv file Saved.")
# Out:
# 탐색할 단어 : 갑분싸
# ------------------------
# - 2023년 11월 : 150개
# - 2023년 10월 : 150개
# - 2023년 09월 : 150개
# ------------------------
# (65 null_element counted)
# Searching finished.
# - - -
# csv file Saved.
